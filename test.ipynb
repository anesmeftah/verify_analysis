# %%
import re

# %%
sentence = "hello world hello"
word_pattern = re.compile(r"world")
result = word_pattern.search(sentence)
print(result.group())
# Out:
# world

# %%
word_pattern = re.compile("hello")
result = word_pattern.search(sentence)
print(result.group())
# Out:
# hello
# {}

# %%
dic = {
    "anas" : "mefteh",
    5 : "age",
    1 : "height"

}

# %%
dic["anas"]
# Out:
# 'mefteh'

# %%
dic[1]
# Out:
# 'height'

# %%
from parser import parse

parsed_two_instances_output = parse(two_instances_output)
print(parsed_two_instances_output)
