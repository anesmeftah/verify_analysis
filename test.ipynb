# %%
import re

# %%
sentence = "hello world hello"
word_pattern = re.compile(r"world")
result = word_pattern.search(sentence)
print(result.group())
# Out:
# world

# %%
word_pattern = re.compile("hello")
result = word_pattern.search(sentence)
print(result.group())
# Out:
# hello

# %%
dic = {
    "anas" : "mefteh",
    5 : "age",
    1 : "height"

}

# %%
dic["anas"]
# Out:
# 'mefteh'

# %%
dic[1]
# Out:
# 'height'

# %%
from importlib import reload
import parser as parser_module
reload(parser_module)
parsed_two_instances_output = parser_module.parser("logs/two_instances_output")
print(parsed_two_instances_output)
# Out:
# {0: TestResult(file_path='logs/two_instances_output', start_idx=8661, end_idx=10042, idx=0, onnx_model='nets/cifar10_2_255_simplified.onnx', vnnlib_spec='specs/cifar10/cifar10_spec_idx_0_eps_0.00784_n1.vnnlib', verified_status='unsafe-pgd', verified_success=True, violations=1, test_type='CE', total_time=0.7059, attack_time=0.3531, cex_saved=True, margins=[3.72991705, 4.85068226, 3.10296106, 2.88564777, -0.07807636, 2.41919184, 4.68555069, 4.35634708, 5.33034468], attack_succeeded=True, initial_crown_bound=0.0, alpha_crown_time=0.0, best_l_after_optimization=0.0, unstable_neurons=0, bab_rounds=0, visited_domains=0, verified_with_init_bound=False), 1: TestResult(file_path='logs/two_instances_output', start_idx=10043, end_idx=15314, idx=1, onnx_model='nets/cifar10_2_255_simplified.onnx', vnnlib_spec='specs/cifar10/cifar10_spec_idx_1_eps_0.00784_n1.vnnlib', verified_status='unknown', verified_success=False, violations=0, test_type='AC', total_time=1.1353, attack_time=0.8042, cex_saved=Fa
# ...

# %%
print(parsed_two_instances_output[0])
# Out:
# TestResult(file_path='logs/two_instances_output', start_idx=8661, end_idx=10042, idx=0, onnx_model='', vnnlib_spec='', verified_status='Unknown', verified_success=False, violations=0, test_type='Unknown', total_time=0.0, attack_time=0.0, cex_saved=False, margins=[], attack_succeeded=False, initial_crown_bound=0.0, alpha_crown_time=0.0, best_l_after_optimization=0.0, unstable_neurons=0, bab_rounds=0, visited_domains=0, verified_with_init_bound=False)

# %%
print(parsed_two_instances_output[1])
# Out:
# TestResult(file_path='logs/two_instances_output', start_idx=10043, end_idx=15314, idx=1, onnx_model='', vnnlib_spec='', verified_status='Unknown', verified_success=False, violations=0, test_type='Unknown', total_time=0.0, attack_time=0.0, cex_saved=False, margins=[], attack_succeeded=False, initial_crown_bound=0.0, alpha_crown_time=0.0, best_l_after_optimization=0.0, unstable_neurons=0, bab_rounds=0, visited_domains=0, verified_with_init_bound=False)
